# %% [markdown]
# <a href="https://www.kaggle.com/code/hamzalogicai/adult-income-dataset-eda-key-insights?scriptVersionId=229023422" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## 📌 Importing Libraries & Loading the Adult Income Dataset
# In this section, we import essential Python libraries and load the **Adult Income Dataset**, which is widely used for income classification tasks. Let's get started! 🚀

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('/kaggle/input/adult-income-dataset/adult.csv')

# %% [markdown]
# ### 🔍 Previewing the Dataset (Top 3 Rows)
# To understand the dataset, we first inspect the **top 3 rows** to get an overview of the available features.

# %%
data.head(3)
# Out:
#    age  workclass  fnlwgt   education  educational-num      marital-status  \
# 0   25    Private  226802        11th                7       Never-married
# 1   38    Private   89814     HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951  Assoc-acdm               12  Married-civ-spouse
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
# 1    Farming-fishing      Husband  White   Male             0             0
# 2    Protective-serv      Husband  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K

# %% [markdown]
# ### 🔍 Checking the Last Few Entries
# By displaying the **last 3 rows**, we ensure that the dataset structure is consistent.

# %%
data.tail(3)
# Out:
#        age     workclass  fnlwgt education  educational-num  \
# 48839   58       Private  151910   HS-grad                9
# 48840   22       Private  201490   HS-grad                9
# 48841   52  Self-emp-inc  287927   HS-grad                9
#
#            marital-status       occupation relationship   race  gender  \
# 48839             Widowed     Adm-clerical    Unmarried  White  Female
# 48840       Never-married     Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse  Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K

# %% [markdown]
# ### 📖 Understanding Key Dataset Columns
# Here’s a quick explanation of important columns in the dataset:
# - **`fnlwgt` (Final Weight):** Represents the weight assigned to each individual.
# - **`educational-num` (Education Level):** A numerical representation of education level.
# - **`capital gain` & `capital loss`**: Profit or loss from asset sales.
# - **`hours-per-week`**: Number of working hours per week.

# %% [markdown]
# ### 📊 Dataset Shape (Rows & Columns)
# Understanding the shape helps us determine the number of **data points (rows) and features (columns)**.

# %%
print("No. of the Rows:",data.shape[0])
print("No. of the Columns:", data.shape[1])
# Out:
# No. of the Rows: 48842
# No. of the Columns: 15

# %% [markdown]
# ### 📋 Dataset Information (Types & Missing Values)
# We check **column types, missing values, and memory usage** to better understand our dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ### 📈 Summary Statistics of the Dataset
# This gives an overview of numerical data, including **mean, min, max, and standard deviation**.

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# ### 🎲 Fetching Random Samples
# To get a sense of data diversity, we randomly sample rows from the dataset.

# %%
data.sample(frac=0.5,random_state=100)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %% [markdown]
# ### 🚨 Checking for Missing Values
# Missing values can impact model performance. Here, we check for null values in the dataset.

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
data["workclass"] = data["workclass"].replace("?", np.nan)
data["occupation"] = data["occupation"].replace("?", np.nan)
data["native-country"] = data["native-country"].replace("?", np.nan)

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing=data.isnull().sum()*100/len(data)

# %%
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %% [markdown]
# ### Dropping the Missing Values

# %%
data.dropna(how='any',inplace=True)

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# ### Check for the Duplicates and Drop them

# %%
data.duplicated().any()
# Out:
# True

# %% [markdown]
# ### Dropping the Unnecessary Columns

# %%
data=data.drop(["fnlwgt","educational-num","capital-gain","capital-loss"],axis=1)

# %%
data.head()
# Out:
#    age  workclass     education      marital-status         occupation  \
# 0   25    Private          11th       Never-married  Machine-op-inspct
# 1   38    Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3   44    Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 5   34    Private          10th       Never-married      Other-service
#
#     relationship   race gender  hours-per-week native-country income
# 0      Own-child  Black   Male              40  United-States  <=50K
# 1        Husband  White   Male              50  United-States  <=50K
# 2        Husband  White   Male              40  United-States   >50K
# 3        Husband  Black   Male              40  United-States   >50K
# 5  Not-in-family  White   Male              30  United-States  <=50K

# %% [markdown]
# # ---Univariate Analysis---

# %% [markdown]
# ### Making the Categories of "education" Column

# %%
def clean_education(x):
    if x=="Bachelors": 
        return "Bachelor's Degree"
    if x=="Assoc-voc":
        return "Bachelor's Degree"
    if x=="Masters": 
        return "Master's Degree" 
    if x=="Prof-school":
         return "Master's Degree"
    if x=="Doctorate":
        return "Doctorate Degree"
    else:
        return "Less than Bachelor's"

# %%
data["education"]=data["education"].apply(clean_education)

# %%
data["education"].unique()
# Out:
# array(["Less than Bachelor's", "Master's Degree", "Bachelor's Degree",
#        'Doctorate Degree'], dtype=object)

# %% [markdown]
# ### What is the Distribution of the Age Column

# %%
data["age"].describe()
# Out:
# count    45222.000000
# mean        38.547941
# std         13.217870
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data["age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Find the Total No. of the People having the Age between 17 to 48

# %%
sum((data["age"]>=17)&(data["age"]<=48))
# Out:
# 34902

# %%
sum(data["age"].between(17,48))
# Out:
# 34902

# %% [markdown]
# ### What is the Distribution of the Workclass Column

# %%
data["workclass"].describe()
# Out:
# count       45222
# unique          7
# top       Private
# freq        33307
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(8,6))
data["workclass"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### How many people have the Bachelors or Masters Degree

# %%
filter1=data["education"]=='Bachelors'
filter2=data["education"]=='Masters'

# %%
len(data[filter1|filter2])
# Out:
# 0

# %% [markdown]
# ### Capitalizing the Column Names

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'gender', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.rename(columns={"age": "Age","workclass":"Workclass","education":"Education","marital-status":"Marital-status","occupation":"Occupation","relationship":"Relationship","race":"Race","gender":"Gender","hours-per-week":"Hours-per-week","native-country":"Native-country","income":"Income"}, inplace=True)

# %% [markdown]
# # ---Bivariate Analysis---

# %% [markdown]
# ### Plot the Graph between the 'Salary' & 'Age'

# %%
sns.barplot(x="Income",y="Age",data=data)
# Out:
# <Axes: xlabel='Income', ylabel='Age'>

# %% [markdown]
# ### Convert Categorical Values to the Numerical Values for 'income' Column

# %%
data.columns
# Out:
# Index(['Age', 'Workclass', 'Education', 'Marital-status', 'Occupation',
#        'Relationship', 'Race', 'Gender', 'Hours-per-week', 'Native-country',
#        'Income'],
#       dtype='object')

# %%
def income_data(income):
    if income=="<=50K":
        return 0
    else:
        return 1
data["Encoded_Salary"]=data["Income"].apply(income_data)

# %%
data.head()
# Out:
#    Age  Workclass             Education      Marital-status  \
# 0   25    Private  Less than Bachelor's       Never-married
# 1   38    Private  Less than Bachelor's  Married-civ-spouse
# 2   28  Local-gov  Less than Bachelor's  Married-civ-spouse
# 3   44    Private  Less than Bachelor's  Married-civ-spouse
# 5   34    Private  Less than Bachelor's       Never-married
#
#           Occupation   Relationship   Race Gender  Hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   Native-country Income  Encoded_Salary
# 0  United-States  <=50K               0
# 1  United-States  <=50K               0
# 2  United-States   >50K               1
# 3  United-States   >50K               1
# ...

# %% [markdown]
# ### Convert the Workclass Column datatype to Categorical datatype

# %%
data["Workclass"].astype("category")
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: Workclass, Length: 45222, dtype: category
# Categories (7, object): ['Federal-gov', 'Local-gov', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay']

# %%
data.dtypes
# Out:
# Age                int64
# Workclass         object
# Education         object
# Marital-status    object
# Occupation        object
# Relationship      object
# Race              object
# Gender            object
# Hours-per-week     int64
# Native-country    object
# Income            object
# Encoded_Salary     int64
# dtype: object

# %%
data2=data.to_csv("Filtered-Adult-Income-Dataset.csv",index=None)
